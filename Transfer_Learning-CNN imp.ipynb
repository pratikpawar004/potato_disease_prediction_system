# %%
#imp :

# Use pretrained model in that .

# %%
#T.L Defination - Transfer Learning is a technique where a model trained on one task is reused and fine-tuned for a related
#       task to improve performance and reduce training time .

# %% [raw]
#  imp theory :
#
# # it meanse use pretrained model
# # standing on the shoulders of giants
#
# # Instead of training a model from scratch, you reuse knowledge from a pre-trained model and adapt it to a new task.new data
#
# # Transfer learning is a technique where a model trained on one task is reused and fine-tuned for a related
# # task to improve performance and reduce training time.
#
# #eg. >> imagenet >>> big dataset
#
# # pretrained models :
# # Examples of alredy trained models :
# #1) VGG.
# #2) ResNet.
# #3) MobileNet.
# #4) Inception.
#
# # Advatages :
#
# # less training time(Fast training)
# # needs less data
# # betteraccuracy
# # save cost
#
# # Idea
# # A model trained on a big dataset already knows useful patterns.
# # You take that knowledge and transfer it to solve a related problem with less data, time, and compute.
#
#
# # >>>>>> images >> images classification ,object detection,disease prediction
# # VGG
# # ResNet
# # MobileNet
# # Inception
#
# # >>>>> TEXT >> Chatbots ,Sentiment analysis,Question answering
# # BERT, GPT, RoBERTa
#
# # >>>> audio >> Speech-to-text,Voice recognition,YouTube auto-captionsGoogle Speech-to-Text API
# # OpenAI Whisper
# # Google Speech-to-Text API
# # Wav2Vec

# %%
#We can use only Models who are free for us :

# %%
# S : Get image fro mtransfer learning :

# %% [markdown]
# ![image.png](attachment:70d7aeff-30ed-4a14-b3bb-d11d4edeafcb.png)![image.png]

# %%
# imp- in TL we have to use dense layers our own but con2d we can use alredytrained model

# %% [markdown]
# # Caste Study -5 : Potato Diseas Prediction With trasfer Learning

# %% [raw]
# 1. VGG Model : visual Geometry Group (its a company name gives to model)

# %%
# VGG 
# VGG16 ,19
# by visual geometry group
# very deep network
# VGG16 >> 13 Convolution layers ,3 Fully Connected layers(Dense) >> image size 224,224,3
# VGG19 >> 16 Convolution layers ,3 Fully Connected layers(Dense) >> image size 224,224,3

# %%
# Step 1 - Read  imges

# %%
# ================== BASIC ==================
import os
from pathlib import Path

# ================== DATA ==================
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ================== IMAGE PROCESSING ==================
import cv2

# ================== TENSORFLOW ==================
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, Input
)
from tensorflow.keras.models import Sequential

# %%
path=r'D:\project\AI\potato_disease_prediction_system\dataset\PlantVillage'

# %%
#to check how many paths we just use glob method to only check :
win_path=Path(path)

# %%
folders=list(win_path.glob('*'))

# %%
folders    # now check all folders paths of images
# Out:
# [WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___healthy'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Late_blight')]

# %%
# to check all images paths catg. wise :

all_imges=list(win_path.glob('*/*.jpg'))

# %%
all_imges
# Out:
# [WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/002a55fb-7a3d-4a3a-aca8-ce2d5ebc6925___RS_Early.B 8170.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/009c8c31-f22d-4ffd-8f16-189c6f06c577___RS_Early.B 7885.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/00d8f10f-5038-4e0f-bb58-0b885ddc0cc5___RS_Early.B 8722.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/0182e991-97f0-4805-a1f7-6e1b4306d518___RS_Early.B 7015.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/02578b86-b234-4ac0-9bc3-691b5610e2bf___RS_Early.B 7562.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/
JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/fe772b3d-351c-4d18-9dcb-26feb90afa0d___RS_Early.B 7456.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___Early_blight/ffef8a3b-3e8a-4c24-a27e-64c41708f7a0___RS_Early.B 7132.JPG'),
#  WindowsPath('D:/project/AI/potato_disease_prediction_system/dataset/PlantVillage/Potato___healthy/00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL 1864.JPG'),
#  ...]

# %%
# check count of all_imges paths :

len(all_imges)
# Out:
# 2150

# %%
# Step 2 - Create imageDataGenerator  Object :

# %%
datagen = ImageDataGenerator(
                             rescale=1./255,   # if u enter float no. instead of intiger value then it use less memory issue 
                             validation_split=0.2,          # 80% train , and 20% use for validation
                             rotation_range=20,           
                             zoom_range=0.2,
                             horizontal_flip=True
                           )

# %%
train_data= datagen.flow_from_directory(path,                        # flow_from_diretory : use for read and get images from path
                            target_size=(224,224),
                            batch_size=32,
                            shuffle=True,
                            class_mode='categorical',
                            subset='training' )
# Out:
# Found 1721 images belonging to 3 classes.

# %%
test_data= datagen.flow_from_directory(path,
                            target_size=(224,224),
                            batch_size=32,
                            shuffle=False,
                            class_mode='categorical',
                            subset='validation' )
# Out:
# Found 429 images belonging to 3 classes.

# %%
1721+429
# Out:
# 2150

# %%
for i,j in train_data:       # it wil extract 32 batch wise imges pth in i and labels j, and labels are one hot encoded. 
    print(i.shape,j.shape)
    break
# Out:
# (32, 224, 224, 3) (32, 3)

# %%
# Step -3 image check and class name classification :

# %%
# check class and its name in dic. form :

class_dict=train_data.class_indices

# %%
class_dict
# Out:
# {'Potato___Early_blight': 0, 'Potato___Late_blight': 1, 'Potato___healthy': 2}

# %%
# for get class names in lists:
class_names=list(train_data.class_indices.keys())

# %%
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
# lets check random image show and label and index check of that image and category :

for i,j in train_data:
    plt.imshow(i[0])
    print(class_names[np.argmax(j[0])])
    break
# Out:
# Potato___Early_blight

# %%
# Step -4 Check Data balance :

# %%
s1=pd.Series(train_data.classes)
s1.value_counts()
# Out:
# 0    800
# 1    800
# 2    121
# Name: count, dtype: int64

# %%
# so the data set is balance

# %%
# step -4 Model Training :

# %% [raw]
# While  model train we CAN use VGG16 and VGG19 model to use:

# %% [raw]
# #1 ) VGG19 :

# %%
from tensorflow.keras.applications import VGG16,VGG19

# %%
base_model = VGG19(
    weights='imagenet',        # imagenet it is  dataset name -whomw it model is trained
    include_top=False,         # We have to our  own dense layer so we use include_top = false to drop models dense layer
    input_shape=(224,224,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step

# %%
#VGG19 = 16 convolution layer , and 3 dense layers

# %%
# 16 layers >> Freeze  - because we have using 16 convlution layers as it  is so it wil not be trained again ,we trained only dense layer
# Why freeze
# We only want to train our new classification layers(fully connected layers)
# We don’t want to re-train the pre-trained knowledge

# %%
# let freeze the convolution layer for not train again and use  dense to train require only :

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
import keras
from keras import Sequential

# %%
final_model = keras.Sequential([
    base_model,
    Flatten(),
    Dense(128,activation='relu'),
    Dropout(0.3),
    Dense(64,activation='relu'),
    Dropout(0.3),
    Dense(3,activation='softmax')
])

final_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

final_model.fit(train_data,validation_data=(test_data),epochs= 2)
# Out:
# Epoch 1/2
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 215s 4s/step - accuracy: 0.6415 - loss: 1.1622 - val_accuracy: 0.8368 - val_loss: 0.4697
# Epoch 2/2
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 216s 4s/step - accuracy: 0.8175 - loss: 0.4782 - val_accuracy: 0.8834 - val_loss: 0.3548

# %%
# Step - 5 Check test accuracy :

# %%
final_model.evaluate(test_data)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.8741 - loss: 0.3514
# [0.3514242172241211, 0.8741258978843689]

# %%
# Step - 6 Predict the model :

# %%
y_pred= final_model.predict(test_data)
y_pred1=[ np.argmax(i) for i in y_pred]
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step

# %%
y_test=test_data.classes

# %%
# step -7 Check metrics :

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[192   7   0]
#  [ 16 184   0]
#  [  5  25   0]]

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       199
#            1       0.85      0.92      0.88       200
#            2       0.00      0.00      0.00        30
#
#     accuracy                           0.88       429
#    macro avg       0.58      0.63      0.61       429
# weighted avg       0.82      0.88      0.84       429
# d:\project\AI\potato_disease_prediction_system\potenv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\project\AI\potato_disease_prediction_system\potenv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\project\AI\potato_disease_prediction_system\potenv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# Step - 8 Save model :

# %%
final_model.save('VGG19_potato.keras')

# %%
# Step -9  we can predict New image using model :

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
path=r'D:\project\AI\potato_disease_prediction_system\dataset\PlantVillage\Potato___Early_blight\0a47f32c-1724-4c8d-bfe4-986cedd3587b___RS_Early.B 8001.JPG'

# %%
img1=load_img(path,target_size=(224,224))

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# now convert img to array ,scale and 4D for use trained maodel :

# %%
img2=img_to_array(img1)
img3=img2/255.0
img4= np.expand_dims(img3,axis=0)   # use for convert in ( 1,256,256,3 ) for single img

# %%
# now check shape :

img4.shape
# Out:
# (1, 224, 224, 3)

# %%
#Now predict that img using model :

# %%
class_names[np.argmax(final_model.predict(img4))]  # it gives probablity in 3 cate. becuse  use class name and argmax to give who is best match and its name
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 'Potato___Early_blight'

# %% [raw]
# #Conclusion - so it  predicting correct for new image .

# %%
# Step - 10  Deployment :  ( need - vs code,git, github,python 3.10 version )

# %% [markdown]
# # Steps For Deployment :
# 1. Create Project Folder. (itvproject)
# 2. Create New Repository. ( repository name - CNN potato_desease_pred )
# 3. Create GitHUb clone. (>>Itvproject >> right click >> gitbash command >> github clone url )
# 4. Open VS Code for clone folder.
# 5. install extentions. (>> python, jupyter, code runner.)
# 6. Copy Python Path to environment veriables .
#  ( >> goto C drive >> show hidden items and get  pythons 310 path >>  C:\Users\admin\AppData\Local\Programs\Python\Python310, and                         Scripts path >> C:\Users\admin\AppData\Local\Programs\Python\Python310\Scripts and copy and pest in envormental verables by searching.
# 7. Create Vertual Environment . ( We can use by - VS-Code terminal and Anaconda prompt ) >> Use vs-code terminal-python -m venv environmnet project neme any , >> eg project_environment or py -3.10 -m venv venv_3_10 for we use vs version 3.10. and then >> .\pyenv\Scripts\activate command use .
# 8. Step-8 create app.py and new1.ipynb
